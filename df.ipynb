# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:\programming languages\Data science\market_fact.csv")
data2=pd.read_csv(r"C:\programming languages\Data science\cust_dimen.csv")
data3=pd.read_csv(r"C:\programming languages\Data science\orders_dimen.csv")
data4=pd.read_csv(r"C:\programming languages\Data science\prod_dimen.csv")
data5=pd.read_csv(r"C:\programming languages\Data science\shipping_dimen.csv")

# %% [markdown]
# data.iloc[rows:columns]

# %%
data.iloc[[3,7,8],:] # first 4 rows of data
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3              43   729.34          14.30                 0.37
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
data.loc[[3,7,8]] # same as above but with loc method instead of iloc method and 1 is the first row and 5 is the last row
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3              43   729.34          14.30                 0.37
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
#set index for order_id

data.set_index('Ord_id',inplace=True)

# %%
data.head()
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5406     4.56           0.93                 0.54
# Ord_5446  1148.90           2.50                 0.59
# Ord_5456   729.34          14.30                 0.37
# Ord_5485  1219.87          26.30                 0.38

# %%
#to select a particular column from the dataframe after set_index

data.loc[['Ord_5446']]
# Out:
#           Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# Ord_5446   -30.51           3.60                 0.56
# Ord_5446  1148.90           2.50                 0.59
# Ord_5446   -47.64           6.15                 0.37

# %%
data.loc[(data.Sales>3000) & (data.Discount>0)] # select rows where sales is greater than 3000 and discount is greater than 0
# Out:
#           Prod_id   Ship_id    Cust_id       Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08              35
# Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10              48
# Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01              43
# Ord_2207  Prod_11  SHP_3093   Cust_839   3364.2480      0.10              15
# Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02              25
# ...           ...       ...        ...         ...       ...             ...
# Ord_3593   Prod_3  SHP_4974  Cust_1274  12073.0600      0.03              39
# Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.0500      0.09              25
# Ord_2624   Prod_4  SHP_3591  Cust_1006   4924.1350      0.07              28
# Ord_2722   Prod_1  SHP_3731  Cust_1006   3508.3300      0.04              21
# Ord_5348  Prod_15  SHP_7469  Cust_1798   3872.8700      0.03              23
#
# ...

# %%
data.Discount.describe()
# Out:
# count    8399.000000
# mean        0.049671
# std         0.031823
# min         0.000000
# 25%         0.020000
# 50%         0.050000
# 75%         0.080000
# max         0.250000
# Name: Discount, dtype: float64

# %%
data.loc[(data.Sales>3000) | (data.Discount>0)] # select rows where sales is greater than 3000 or discount is greater than 0
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...           ...       ...        ...        ...       ...             ...
# Ord_5348   Prod_8  SHP_7470  Cust_1798   356.7200      0.07               9
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
#
# ...

# %%
data.loc[~(data.Sales>3000) | ~(data.Discount>0)] # select rows where sales is not greater than 3000 or discount is not greater than 0
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03              23
# ...           ...       ...        ...        ...       ...             ...
# Ord_5348   Prod_8  SHP_7470  Cust_1798   356.7200      0.07               9
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
# ...
